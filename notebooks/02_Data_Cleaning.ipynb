# %% [markdown]
# # Data Cleaning & Preparation
#
# ## Objective
#
# Prepare the Walmart Sales dataset for analysis by:
# - Converting data types
# - Handling missing values
# - Checking duplicates
# - Detecting outliers
# - Merging datasets
# - Creating new analytical features

# %%
import pandas as pd
import numpy as np

pd.set_option("display.max_columns", None)

# %%
train = pd.read_csv("D:\\Financial-Data-Analytics-Forecasting\\data\\train.csv")
features = pd.read_csv("D:\\Financial-Data-Analytics-Forecasting\\data\\features.csv")
stores = pd.read_csv("D:\\Financial-Data-Analytics-Forecasting\\data\\stores (1).csv")
test = pd.read_csv("D:\\Financial-Data-Analytics-Forecasting\\data\\test.csv")
